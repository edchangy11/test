# %%
from sklearn.datasets import load_digits
digits = load_digits()

# %%
print("images shape: %s" % str(digits.images.shape))
print("targets shape: %s" % str(digits.target.shape))
# Out:
# images shape: (1797, 8, 8)
# targets shape: (1797,)

# %%
digits.images[0]

# %%
X = digits.data.reshape(-1, 64)

# %%
y = digits.target

# %%
print(X.shape)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X);

# %%
X_pca = pca.transform(X)
X_pca.shape
plt.figsize(16, 10)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-a84a41935604> in <module>()
#       1 X_pca = pca.transform(X)
#       2 X_pca.shape
# ----> 3 plt.figsize(16, 10)
#       4 plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y);
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'figsize'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y);

# %%
param_grid = {'C': 10. ** np.arange(-3, 4)}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-bf50f160406a> in <module>()
# ----> 1 param_grid = {'C': 10. ** np.arange(-3, 4)}
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
param_grid = {'C': 10. ** np.arange(-3, 4)}

# %%
param_grid
# Out:
# {'C': array([  1.00000000e-03,   1.00000000e-02,   1.00000000e-01,
#           1.00000000e+00,   1.00000000e+01,   1.00000000e+02,
#           1.00000000e+03])}

# %%
param_grid
# Out:
# {'C': array([  1.00000000e-03,   1.00000000e-02,   1.00000000e-01,
#           1.00000000e+00,   1.00000000e+01,   1.00000000e+02,
#           1.00000000e+03])}

# %%
np.set_printoptions(formatter={'float_kind':'{:f}'.format})

# %%
param_grid
# Out:
# {'C': array([0.001000, 0.010000, 0.100000, 1.000000, 10.000000, 100.000000,
#         1000.000000])}
